# %% [markdown]
# # Example 1:

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
wh_output_dir = '/Users/lejoflores/data/WH_SIM_channel_routing_00/' # <- Change this to the correct path

lsm_filebase = '*.LDASOUT_DOMAIN1'

wh_ds = xr.open_mfdataset(wh_output_dir+lsm_filebase)
print(wh_ds)
# Out:
# <xarray.Dataset>
# Dimensions:         (reference_time: 1, snow_layers: 3, soil_layers_stag: 4, time: 121, vis_nir: 2, x: 66, y: 49)
# Coordinates:
#   * reference_time  (reference_time) datetime64[ns] 2010-06-01
#   * x               (x) float64 -1.444e+06 -1.443e+06 ... -1.38e+06 -1.379e+06
#   * y               (y) float64 -6.005e+05 -5.995e+05 ... -5.535e+05 -5.525e+05
#   * time            (time) datetime64[ns] 2010-06-01 ... 2010-06-06
# Dimensions without coordinates: snow_layers, soil_layers_stag, vis_nir
# Data variables:
#     crs             (time) |S1 b'' b'' b'' b'' b'' b'' ... b'' b'' b'' b'' b''
#     IVGTYP          (time, y, x) float32 dask.array<shape=(121, 49, 66), chunksize=(1, 49, 66)>
#     ISLTYP          (time, y, x) float32 dask.array<shape=(121, 49, 66), chunksize=(1, 49, 66)>
#     FVEG            (time, y, x) float32 dask.array<shape=(121, 49, 66), chunksize=(1, 49, 66)>
# ...

# %%
wh_ds.RAINRATE.mean(dim=('x','y')).plot()
# Out:
# /Users/lejoflores/miniconda3/lib/python3.7/site-packages/dask/array/numpy_compat.py:28: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
wh_ds.LH.mean(dim=('x','y')).plot()

# %%
wh_ds.ACCET.mean(dim=('x','y')).plot()

# %%
wh_ds.SNOWH[-1].plot()

# %%
wh_ds.SNOWH.mean(dim=('x','y')).plot()

# %%
wh_ds.SOIL_W[-1].mean(dim='soil_layers_stag').plot()

# %%
wh_ds.SOIL_W[0].mean(dim='soil_layers_stag').plot()

# %%
wh_ds.SOIL_W.mean(dim=('x','y','soil_layers_stag')).plot()
